# %%
# lecture2-exercises.ipynb
# Mason del Rosario
# STA208 Spring 2020

import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %% [markdown]
# # Exercise 2.1
# 1. Need to standardize
# 2. You want your trained predictor to do well on unseen data, so test data remains untouched during training.
# 3. Try a large range of $K$, plot MSE as function of $K$

# %%
# 0: import data with pandas
datapath = "../../data/"
filename = datapath + 'winequality-red.csv'
wine = pd.read_csv(filename,delimiter=';')
wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
# train_test_split dataset
from skleran.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
name_num = len(names)
X=wine_ar[:,0:name_num-1]
y=wine_ar[:,-1]
print(X)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.5
)
# Out:
# [[ 7.4    0.7    0.    ...  3.51   0.56   9.4  ]
#  [ 7.8    0.88   0.    ...  3.2    0.68   9.8  ]
#  [ 7.8    0.76   0.04  ...  3.26   0.65   9.8  ]
#  ...
#  [ 6.3    0.51   0.13  ...  3.42   0.75  11.   ]
#  [ 5.9    0.645  0.12  ...  3.57   0.71  10.2  ]
#  [ 6.     0.31   0.47  ...  3.39   0.66  11.   ]]

# %%
# fit OLS regression model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
reg = LinearRegression().fit(X_train,y_train)
print('-> Test R^2: {:0.3f}'.format(reg.score(X_test, y_test)))
y_hat = reg.predict(X_test)
mse = mean_squared_error(y_test,y_hat)
print("-> Test MSE: {:0.3f}".format(mse))
print("-> Test Variance: {:0.3f}".format(y_test.var()))
# Out:
# -> Test R^2: 0.313
# -> Test MSE: 0.441
# -> Test Variance: 0.641
